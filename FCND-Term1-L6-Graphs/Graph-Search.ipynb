# %% [markdown]
# ## Finding Your Way In The City (Graph Edition)
# In this notebook your attention will shift from grids to graphs. At least for search ... the world representation is still a grid. You likely noticed in the previous notebook the generated paths flew as close to the obstacle / safety space as possible.
#
# Using Voronoi graphs and the medial axis transform we can find paths which maximize safety from obstacles. In addition, graph representation allows further optimizations and more succinct queries.

# %%
# OK this might look a little ugly but...
# Just waiting on eng to install these in the backend!
import sys
# !{sys.executable} -m pip install -Iv networkx==2.0
import pkg_resources
pkg_resources.require("networkx==2.0")
import networkx as nx


import numpy as np
import matplotlib.pyplot as plt
from grid import create_grid_and_edges
import numpy.linalg as LA
# %matplotlib inline
# Out:
# Requirement already satisfied: bresenham in /opt/conda/lib/python3.6/site-packages
# Collecting networkx==2.0
#   1 location(s) to search for versions of networkx:
#   * https://pypi.python.org/simple/networkx/
#   Getting page https://pypi.python.org/simple/networkx/
#   Looking up "https://pypi.python.org/simple/networkx/" in the cache
#   Current age based on date: 16
#   Freshness lifetime from max-age: 600
#   Freshness lifetime from request max-age: 600
#   The response is "fresh", returning cached response
#   600 > 16
#   Analyzing links from page https://pypi.python.org/simple/networkx/
#     Skipping link https://pypi.python.org/packages/01/01/7b7056bc70c410e17a530d5219f64cb2d8ca74569213c4ac90470c819566/networkx-1.7rc1-py2.6.egg#md5=9cf8e0e59ca11297c37dadd1dbd4484c (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Skipping link https://pypi.python.org/packages/03/66/6f7344240222219b93472b479dfb4f84205a05db9bfb5270fcc7ee5f9c56/networkx-1.4rc1-py3.2.egg#md5=932fa909f25484068f25842ea1e5bbc7 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/0c/d0/120c266d9e6ab1276db7332b92c051e5cc456bf98ed5e967a726135daaf9/networkx-1.11rc2-py2.py3-none-any.whl#md5=ae10a8297e4848115039246c02bb1d82 (from https://pypi.python.org/simple/networkx/), version: 1.11rc2
#     Skipping link https://pypi.python.org/packages/0d/6f/9e685de61145e554036b727de3c4074c6d4c8f12bb297929e3de875f1520/networkx-0.36.win32.exe#md5=96d027f31860bf5a6b5a624c0f5616fa (from https://pypi.python.org/simple/networkx/); unsupported archive format: .exe
#     Skipping link https://pypi.python.org/packages/0f/de/e75942a51224fea54cd5439c5ffc857cc96e38376fa7be5ba02fdadd146c/networkx-1.8rc1-py3.2.egg#md5=e4d7bdff9286ee4b232dec490d8fdafd (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Skipping link https://pypi.python.org/packages/11/09/a5bb974e846b03f9b94cc6f8322aec2ed64acd4c76c81ca7226b1ae49e93/networkx-0.99-py2.4.egg#md5=659132ddf83013a72acea973e2b93657 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Skipping link https://pypi.python.org/packages/11/22/92049588d5cb27a5ef4c8cdc344c0c32421205898fb8c8630152935b2f83/networkx-1.7-py2.7.egg#md5=1d4c59f1e894f39f8928be8718905969 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/11/42/f951cc6838a4dff6ce57211c4d7f8444809ccbe2134179950301e5c4c83c/networkx-2.1.zip#md5=4a2c2a62dfc46ba7d594daca7c834995 (from https://pypi.python.org/simple/networkx/), version: 2.1
#     Skipping link https://pypi.python.org/packages/12/8c/f721d617ebced122efed2898369d5e0484e4e042a40c629b6462d132b6f8/networkx-1.3-py2.7.egg#md5=93aaae77abd632a4aa58cf4493f04bf4 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Skipping link https://pypi.python.org/packages
#     Found link https://pypi.python.org/packages/c2/93/dbb41b03cf7c878a7409c8e92226531f840a423c9309ea534873a83c9192/networkx-1.11.tar.gz#md5=6ef584a879e9163013e9a762e1cf7cd1 (from https://pypi.python.org/simple/networkx/), version: 1.11
#     Found link https://pypi.python.org/packages/c2/fe/447e1de892494a2b18294e6ec848b6843eb9f1f4c5ff06ada94a4fe1caff/networkx-1.10rc2-py2.py3-none-any.whl#md5=4008fe1d8f328b8d12a99a26b1494a7e (from https://pypi.python.org/simple/networkx/), version: 1.10rc2
#     Skipping link https://pypi.python.org/packages/c3/0d/fed3d0653d39f625e2fe09fd9fe9600160db8f7911257e43cb66b00c81da/networkx-1.4-py2.7.egg#md5=1b3c00fa02369c0c527b6a500620a639 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/c3/62/ee2418a572912cdd592d39a8cf616d656c973365577ba4293acdc8c5d5c4/networkx-1.9.1-py2.py3-none-any.whl#md5=15bb60c9b386563a6d4765264f5bf687 (from https://pypi.python.org/simple/networkx/), version: 1.9.1
#     Skipping link https://pypi.python.org/packages/c5/cc/c90fae7309739e171691729d3fc6a91415e69fb83ac547ee1b42557228ba/networkx-0.35-py2.5.egg#md5=a02fbc80ed9979411749588c2a1509c6 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/c8/9c/b68cf48efbc8306454f815a45730e14b01b1c5d9c660efd9149139830266/networkx-1.3rc1.tar.gz#md5=22f3b213721243ffdf878692c9bfdf11 (from https://pypi.python.org/simple/networkx/), version: 1.3rc1
#     Found link https://pypi.python.org/packages/cb/fc/9b1c805b9abe249b9ce786d2ac9e6808d7776237d195365d50188a38dc30/networkx-1.10.tar.gz#md5=eb7a065e37250a4cc009919dacfe7a9d (from https://pypi.python.org/simple/networkx/), version: 1.10
#     Found link https://pypi.python.org/packages/cf/59/82e171fed7776708e5c20b77ad553e8fb2c265c4dce726e92296b6200e12/networkx-1.11rc2.zip#md5=abeb4f38e3fb994c27bd6236a2dfc43c (from https://pypi.python.org/simple/networkx/), version: 1.11rc2
#     Found link https://pypi.python.org/packages/d3/2c/e473e54afc9fae58dfa97066ef6709a7e35a1dd1c28c5a3842989322be00/networkx-1.11-py2.py3-none-any.whl#md5=ab17331efa70d929d3c8d95c107b1f43 (from https://pypi.python.org/simple/networkx/), version: 1.11
#     Skipping link https://pypi.python.org/packages/d4/8c/e85e366903f3a191b4c167ef368cfeca2c761dfd547c5d2b41e66fb25df9/networkx-0.99.win32.exe#md5=cefc81a24347afd049247ee9d6c773f1 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .exe
#     Found link https://pypi.python.org/packages/d6/16/335aaac38b9251b1e64d451c05009ac61744e591c03e4a4527091e1726ba/networkx-1.11rc2.tar.gz#md5=5eb8998a72da90710702c634ab75fd56 (from https://pypi.python.org/simple/networkx/), version: 1.11rc2
#     Found link https://pypi.python.org/packages/d8/af/ad3b6fbaa6de8f580359f4a6526b60a2cbcbd882eb247905fcb1b47585d3/networkx-1.0rc1.zip#md5=91333d2aa72a7a6104223b29d58a9e16 (from https://pypi.python.org/simple/networkx/), version: 1.0rc1
#     Skipping link https://pypi.python.org/packages/d9/22/f20efeb15d519c833704239f07fb5de34d714dae153dee8b322f51a68cc8/networkx-1.6-py2.7.egg#md5=846f86c5af02c61ad6ed3ba3bcc3753d (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages
from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/f1/8e/f6f345ed7b228d080e338eac5a6bcce2260390468ae9130dcb67096f59c4/networkx-1.1.tar.gz#md5=f72e260447711ca0fd7b1b1de5a2396d (from https://pypi.python.org/simple/networkx/), version: 1.1
#     Skipping link https://pypi.python.org/packages/f4/09/81fa2ad8c9851c0a00f627690442cde31db062d9ee7e8bb5ab63e3ee36b2/networkx-1.3-py3.2.egg#md5=640babb460105ec2ba94eec123a6437f (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/f5/4b/7c81c5fefd3d1714733291d5ef1ffb1809202260d3c34c690c16b5c77170/networkx-1.3rc1.zip#md5=7b5b22430434de4e74665639a506d2e5 (from https://pypi.python.org/simple/networkx/), version: 1.3rc1
#     Found link https://pypi.python.org/packages/f5/bd/604b69dbf95d116a6eb3be57a262cbf1e9fd557a7781125a93511795835b/networkx-1.2.zip#md5=fdc4c71b1dffd096eb112d99ddee8813 (from https://pypi.python.org/simple/networkx/), version: 1.2
#     Skipping link https://pypi.python.org/packages/f9/89/70738446d45e167c396ba03de7395b5a33ccb91b5982fefa193dd0024913/networkx-1.8-py3.3.egg#md5=b69a1b33e218f5dc26c8ca8ac5a1dc33 (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Skipping link https://pypi.python.org/packages/fb/48/6c835488a11d36e9fcdb4db61cce3d2f0933d63b4a8ae1954d20166b56a1/networkx-1.4rc1-py2.7.egg#md5=95c298b9086887ad84542bd4e37f7b1c (from https://pypi.python.org/simple/networkx/); unsupported archive format: .egg
#     Found link https://pypi.python.org/packages/fe/6e/c496a3b04b02726a9800f37162615a2f042df3c08fa88e7bb88b0915ca74/networkx-0.99.zip#md5=a4fc5074ee0f0f4959b47d25c8d8b343 (from https://pypi.python.org/simple/networkx/), version: 0.99
#   Using version 2.0 (newest of versions: 2.0)
#   Using cached wheel link: file:///root/.cache/pip/wheels/27/82/23/785d5d01de2271edf929ac2761cb5dafc0dfa76a0861bfd128/networkx-2.0-py2.py3-none-any.whl
# Collecting decorator>=4.1.0 (from networkx==2.0)
#   1 location(s) to search for versions of decorator:
#   * https://pypi.python.org/simple/decorator/
#   Getting page https://pypi.python.org/simple/decorator/
#   Looking up "https://pypi.python.org/simple/decorator/" in the cache
#   Current age based on date: 15
#   Freshness lifetime from max-age: 600
#   Freshness lifetime from request max-age: 600
#   The response is "fresh", returning cached response
#   600 > 15
#   Analyzing links from page https://pypi.python.org/simple/decorator/
#     Found link https://pypi.python.org/packages/00/cc/dd79ea98a0ff5a01d714c37eddd99cd0a71557113f1511921d1ef9a083b8/decorator-4.0.11-py2.py3-none-any.whl#md5=0b3b4cad44b9ea580a7458c8f3e5e506 (from https://pypi.python.org/simple/decorator/), version: 4.0.11
#     Found link https://pypi.python.org/packages/0c/6f/e81f4ef13afe85a89bb2e447b7d6635b5687f701f7d64b0a487330972993/decorator-4.1.0.tar.gz#md5=c1aada8dd540710490a97e6ec243e75b (from https://pypi.python.org/simple/decorator/), version: 4.1.0
#     Found link https://pypi.python.org/packages/13/8a/4eed41e338e8dcc13ca41c94b142d4d20c0de684ee5065523fee406ce76f/decorator-4.0.10.tar.gz#md5=434b57fdc3230c500716c5aff8896100 (from https://pypi.python.org/simple/decorator/), version: 4.0.10
#     Found link https://pypi.python.org/packages/2f/77/c2710fc6e73a612bc154e24ca34252c11a3682a997039ad7c0a0bf56f9bb/decorator-4.0.3.tar.gz#md5=deb7b7fce8c7cba87a758b1c816a99a1 (from https://pypi.python.org/simple/decorator/), version: 4.0.3
#     Found link https://pypi.python.org/packages/33/de/f87b10da4cebbea3f33386cc73e495a2a4a2ddfafaae8d58ac80b4d9494b/decorator-4.0.6-py2.py3-none-any.whl#md5=c83705ce9746668d89806d9cce7fdd72 (from https://pypi.python.org/simple/decorator/), version: 4.0.6
#     Found link https://pypi.python.org/packages/34/2b/ab9649b98c1ac3e3f0a070ff76896eeaa1144cbe8bab02b4711738478526/decorator-4.0.1.tar.gz#md5=2613740b6d2c56c9dd3a20fd5f9bd2a7 (from https://pypi.python.org/simple/decorator/), version: 4.0.1
#     Found link https://pypi.python.org/packages/35/3a/42566eb7a2cbac774399871af04e11d7ae3fc2579e7dae85213b8d1d1c57/decorator-3.4.2.tar.gz#md5=9e0536870d2b83ae27d58dbf22582f4d (from https://pypi.python.org/simple/decorator/), version: 3.4.2
#     Found link https://pypi.python.org/packages/48/22/58f948f7bc5de0b1aa1aaddb0d294b9333495009dda1fb08443dec5381a9/decorator-3.3.1.tar.gz#md5=a8fc62acd705f487a71bc406e19e0cc6 (from https://pypi.python.org/simple/decorator/), version: 3.3.1
#     Found link https://pypi.python.org/packages/4e/bf/d7a2984e5c09312c93338c2ee0223bb46ca1ee00bad9cff33779eb21526b/decorator-3.3.3.tar.gz#md5=f5a0227cb1c34a0e7d5b7f9cd2ae3135 (from https://pypi.python.org/simple/decorator/), version: 3.3.3
#     Found link https://pypi.python.org/packages/53/24/cc53f9f216dd5ef269e0af7c7651cbda162554a5b088621a205961c07a6f/decorator-4.0.10-py2.py3-none-any.whl#md5=ae79c6013101cdfee49146bacbc3fb10 (from https://pypi.python.org/simple/decorator/), version: 4.0.10
#     Found link https://pypi.python.org/packages/57/07/f22e2c41d23d71d482b1c4e45fa3e51af4d521da17c5cca0ffd7b30f6789/decorator-4.0.0.tar.gz#md5=f417f7ad86de03eb37ecc20c3125f649 (from https://pypi.python.org/simple/decorator/), version: 4.0.0
#     Found link https://pypi.python.org/packages/62/ad/ecdc6b1d0241bf4bf3d7f65b1576c4d8ff1d057bea786e080ae843c991b0/decorator-4.0.0-py2.py3-none-any.whl#md5=8e1f3e1d39cc5ca7bd9f651ee92ae7c1 (from https://pypi.python.org/simple/decorator/), version: 4.0.0
#     Found link https://pypi.python.org/packages/68/04/621a0f896544814ce6c6a0e6bc01d19fc41d245d4515a2e4cf9e07a45a12/decorator-4.0.9.tar.gz#md5=f12c5651ccd707e12a0abaa4f76cd69a (from https://pypi.python.org/simple/decorator/), version: 4.0.9
#     Found link https://pypi.python.org/packages/70/f1/cb9373195639db13063f55eb06116310ad691e1fd125e6af057734dc44ea/decorator-4.2.1.tar.gz#md5=e886337e9f70e70d45d67266b8e66044 (from https://pypi.python.org/simple/decorator/), version: 4.2.1
#     Found link https://pypi.python.org/packages/7a/ee/c8a9600cd5b5e09d08828371f9010926bf9cc67522be03d131529f7237a3/decorator-4.0.4.tar.gz#md5=dd3a0669e1e6f09699eefa2c7fbd9756 (from https://pypi.python.org/simple/decorator/), version: 4.0.4
#     Found link https://pypi.python.org/packages/7d/ca/493b2377bf42d57bdd985c31975be3d2b500ad9079199cecb7633e8e2cde/decorator-4.0.9-py2.py3-none-any.whl#md5=8bb72dc6e496c3f748d7aeabe4bfe4ff (from https://pypi.python.org/simple/decorator/), version: 4.0.9
#     Found link https://pypi.python.org/packages/86/12/f0d5879474424dd9379ec330975a85891fe06dbf4861acbe4988c1c3047b/decorator-4.0.3-py2.py3-none-any.whl#md5=d9e8e8f4a3b2865b21e119bc9b1ab5ed (from https://pypi.python.org/simple/decorator/), version: 4.0.3
#     Found link https://pypi.python.org/packages/99/b6/c61aa88527801323afd3b6aa599f98eb191d2026fce53a195be22dd79745/decorator-4.1.1-py2.py3-none-any.whl#md5=3814f2468971f6bf10b2069cb15c41ff (from https://pypi.python.org/simple/decorator/), version: 4.1.1
#     Found link https://pypi.python.org/packages/a1/4e/c42167ba5c3192bed633726d39d7896cc55d4fa3ec4a1fb60cd3a53fc4c7/decorator-4.1.2-py2.py3-none-any.whl#md5=0bec41a29a46fde7a205ba8aabaabf91 (from https://pypi.python.org/simple/decorator/), version: 4.1.2
#     Found link https://pypi.python.org/packages/a3/8e/530a76d6608260902970ecd8cf68a199593d7a76162d6d4d09ccc17c0888/decorator-4.0.2-py2.py3-none-any.whl#md5=6e6b46b2ed8ed0ebd45938c8e748a0a3 (from https://pypi.python.org/simple/decorator/), version: 4.0.2
#     Found link https://pypi.python.org/packages/a8/26/93428c6d2885c8b5f2f0c569f8cb9c40bb4ab85c270e52bfb481c7bb1529/decorator-4.1.1.tar.gz#md5=dbae97f4c5228c0c8616ac0252f57874 (from https://pypi.python.org/simple/decorator/), version: 4.1.1
#     Found link https://pypi.python.org/packages/bb/e0/f6e41e9091e130bf16d4437dabbac3993908e4d6485ecbc985ef1352db94/decorator-4.1.2.tar.gz#md5=a0f7f4fe00ae2dde93494d90c192cf8c (from https://pypi.python.org/simple/decorator/), version: 4.1.2
#     Found link https://pypi.python.org/packages/c3/bc/3a76f2d58894583970132914ccf819d396dc168e555792cc8147519e4a7e/decorator-4.1.0-py2.py3-none-any.whl#md5=0e730118662530c236b6cdeb38c61c1d (from https://pypi.python.org/simple/decorator/), version: 4.1.0
#     Found link https://pypi.python.org/packages/c5/dd/2981cc27073de0df432d95f194cf9be333f7e373fcea7962488d5755c1a4/decorator-4.0.2.tar.gz#md5=033c9563af492c4ce2680ee6ca481fa7 (from https://pypi.python.org/simple/decorator/), version: 4.0.2
#     Found link https://pypi.python.org/packages/cc/ac/5a16f1fc0506ff72fcc8fd4e858e3a1c231f224ab79bb7c4c9b2094cc570/decorator-4.0.11.tar.gz#md5=73644c8f0bd4983d1b6a34b49adec0ae (from https://pypi.python.org/simple/decorator/), version: 4.0.11
#     Found link https://pypi.python.org/packages/d0/4c/7664e6264b58fbc8a89b88f275cfc518b5c42cf71a55e6b716188ccc64e2/decorator-4.0.4-py2.py3-none-any.whl#md5=18e6961dc58bd0e9cc5f8db265f7d5e4 (from https://pypi.python.org/simple/decorator/), version: 4.0.4
#     Found link https://pypi.python.org/packages/e1/5a/53db15bf367d2028bdc6700dbdf1bdfab46b9f208b7516952817c0808118/decorator-4.2.1-py2.py3-none-any.whl#md5=ee1340f665cc86f7ee03fea0030fa2d4 (from https://pypi.python.org/simple/decorator/), version: 4.2.1
#     Found link https://pypi.python.org/packages/ea/40/0c221a2d74f91c6966f77615b6d978bd32b34922827cbf80a3654f396011/decorator-4.0.1-py2.py3-none-any.whl#md5=1fba6846ec2e2623d449f3e47252917e (from https://pypi.python.org/simple/decorator/), version: 4.0.1
#     Found link https://pypi.python.org/packages/ed/69/24345e0d49c700557f135d01f5de03345368303fdee81b54eae28bf6143d/decorator-4.0.8-py2.py3-none-any.whl#md5=3bf05818357035898005c7809d7e47e9 (from https://pypi.python.org/simple/decorator/), version: 4.0.8
#     Found link https://pypi.python.org/packages/f3/26/876d492f2394f29401eb652ddfa53dec2bc8721861c7fe0dce1b5d0d2b6a/decorator-3.4.0.tar.gz#md5=1e8756f719d746e2fc0dd28b41251356 (from https://pypi.python.org/simple/decorator/), version: 3.4.0
#     Found link https://pypi.python.org/packages/f5/52/a4f3efffddfdfa602b9bb9d77ee984e2ee7c6c62a87de3016e51f5a83a75/decorator-3.3.2.tar.gz#md5=446f5165af67eb0fcd8fd28abd259e86 (from https://pypi.python.org/simple/decorator/), version: 3.3.2
#     Found link https://pypi.python.org/packages/f6/5d/515561750323dd09539a645b5ea43ec418a5d91a3933ecea0605b3c6caac/decorator-4.0.8.tar.gz#md5=58a3c5069a6ca1b5a265ece1ba7de8f1 (from https://pypi.python.org/simple/decorator/), version: 4.0.8
#     Found link https://pypi.python.org/packages/f7/34/204c9d36ce74607ecf399682121d6c7f05dc8c491fc1f644d86d0808d44a/decorator-4.0.6.tar.gz#md5=b17bfa17c294d33022a89de0f61d38fe (from https://pypi.python.org/simple/decorator/), version: 4.0.6
#   Using version 4.2.1 (newest of versions: 4.1.0, 4.1.1, 4.1.2, 4.2.1)
#   Looking up "https://pypi.python.org/packages/e1/5a/53db15bf367d2028bdc6700dbdf1bdfab46b9f208b7516952817c0808118/decorator-4.2.1-py2.py3-none-any.whl" in the cache
#   Current age based on date: 1098
#   Freshness lifetime from max-age: 31557600
#   The response is "fresh", returning cached response
#   31557600 > 1098
#   Using cached decorator-4.2.1-py2.py3-none-any.whl
#   Downloading from URL https://pypi.python.org/packages/e1/5a/53db15bf367d2028bdc6700dbdf1bdfab46b9f208b7516952817c0808118/decorator-4.2.1-py2.py3-none-any.whl#md5=ee1340f665cc86f7ee03fea0030fa2d4 (from https://pypi.python.org/simple/decorator/)
# Installing collected packages: decorator, networkx
# Successfully installed decorator-4.2.1 networkx-2.0
# Cleaning up...

# %%
plt.rcParams['figure.figsize'] = 12, 12

# %%
nx.__version__
# Out:
# '2.0'

# %%
plt.rcParams['figure.figsize'] = 12, 12

# %%
# This is the same obstacle data from the previous lesson.
filename = 'colliders.csv'
data = np.loadtxt(filename, delimiter=',', dtype='Float64', skiprows=2)
print(data)

# %% [markdown]
# Starting and goal positions in *(north, east)*.

# %%
start_ne = (25,  100)
goal_ne = (750., 370.)

# %%
# Static drone altitude (metres)
drone_altitude = 5

# %%
# This is now the routine using Voronoi
grid, edges = create_grid_and_edges(data, drone_altitude)
print(len(edges))

# %% [markdown]
# Plot the edges on top of the grid along with start and goal locations.

# %%
# equivalent to
# plt.imshow(np.flip(grid, 0))
plt.imshow(grid, origin='lower', cmap='Greys') 

for e in edges:
    p1 = e[0]
    p2 = e[1]
    plt.plot([p1[1], p2[1]], [p1[0], p2[0]], 'b-')

    
plt.plot(start_ne[1], start_ne[0], 'rx')
plt.plot(goal_ne[1], goal_ne[0], 'rx')

plt.xlabel('EAST')
plt.ylabel('NORTH')
plt.show()

# %% [markdown]
# We now have a graph, well at least visually. The next step is to use the [`networkx`](https://networkx.github.io) to create the graph. **NetworkX** is a popular library handling anything and everything related to graph data structures and algorithms.
#
# **NOTE:** In the initial import above it was imported with the `nx` alias.
#
# You're encouraged to read the documentation but here's a super quick tour:
#
# 1. Create a graph:
#
# ```
# G = nx.Graph()
# ```
#
# 2. Add an edge:
#
# ```
# p1 = (10, 2.2)
# p2 = (50, 40)
# G = nx.add_edge(p1, p2)
# ```
#
# 3 Add an edge with a weight:
#
# ```
# p1 = (10, 2.2)
# p2 = (50, 40)
# dist = LA.norm(np.array(p2) - np.array(p1))
# G = nx.add_edge(p1, p2, weight=dist)
# ```

# %%
# TODO: create the graph with the weight of the edges
# set to the Euclidean distance between the points

# %% [markdown]
# You need a method to search the graph, and you'll adapt A* in order to do this. The notable differences being the actions are now the outgoing edges and the cost of an action is that weight of that edge.

# %%
from queue import PriorityQueue

def heuristic(n1, n2):
    #TODO: define a heuristic
    return 0

###### THIS IS YOUR OLD GRID-BASED A* IMPLEMENTATION #######
###### With a few minor modifications it can work with graphs! ####
#TODO: modify A* to work with a graph
def a_star(graph, heuristic, start, goal):
    
    path = []
    queue = PriorityQueue()
    queue.put((0, start))
    visited = set(start)

    branch = {}
    found = False
    
    while not queue.empty():
        item = queue.get()
        current_cost = item[0]
        current_node = item[1]

        if current_node == goal:        
            print('Found a path.')
            found = True
            break
            
        else:
            for action in valid_actions(grid, current_node):
                # get the tuple representation
                da = action.delta
                cost = action.cost
                next_node = (current_node[0] + da[0], current_node[1] + da[1])
                new_cost = current_cost + cost + h(next_node, goal)
                
                if next_node not in visited:                
                    visited.add(next_node)               
                    queue.put((new_cost, next_node))
                    
                    branch[next_node] = (new_cost, current_node, action)
             
    path = []
    path_cost = 0
    if found:
        
        # retrace steps
        path = []
        n = goal
        path_cost = branch[n][0]
        while branch[n][1] != start:
            path.append(branch[n][2])
            n = branch[n][1]
        path.append(branch[n][2])
            
    return path[::-1], path_cost

# %% [markdown]
# ### Solution
#
# This solution consists of two parts:
#
# 1. Find the closest point in the graph to our current location, same thing for the goal location.
# 2. Compute the path from the two points in the graph using the A* algorithm.
# 3. Feel free to use any of the path pruning techniques to make the path even smaller!
# 4. Plot it up to see the results!

# %% [markdown]
# ### TODO: Write your solution!
